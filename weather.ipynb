# %%
import numpy as np
import pandas as pd

# %%
label=pd.read_csv('train/train.csv')

# %%
label = np.array(label)

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread('train/data/'+label[2,0])

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (267, 400, 3)

# %%
data=[]
labels=[]
