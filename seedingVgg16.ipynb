# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
import os
import glob
labels = np.zeros((4750,12),dtype="int32")
imgs = os.listdir("./train1")
count = 0
count1 = 0
images = []
for i in imgs:
    imgs1 = os.listdir("./train1/"+i)
    for j in imgs1:
        img = image.load_img('./train1/'+i+'/'+j, target_size=(150, 150))
        img = image.img_to_array(img)
        images.append(img)
        labels[count1,count] = 1
        count1 = count1 + 1
    count = count + 1
images = np.array(images)/255
labels = np.array(labels)
print(count)
# Out:
# 12

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)
#bottleneck_features_validation = model.predict(images)
#np.save('bottleneck_features_validation.npy', bottleneck_features_validation)

# %%
from sklearn.cross_validation import train_test_split
import random
train_data = np.load('bottleneck_features_train.npy')
X_train, X_valid, y_train, y_valid = train_test_split(train_data, labels, test_size=0.3, random_state=random.randint(0,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c0c23580e98e> in <module>()
#       2 import random
#       3 train_data = np.load('bottleneck_features_train.npy')
# ----> 4 X_train, X_valid, y_train, y_valid = train_test_split(train_data, labels, test_size=0.3, random_state=random.randint(0,100))
#
# NameError: name 'labels' is not defined

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.utils import np_utils
from keras.models import load_model
from keras import backend as K
# the features were saved in order, so recreating the labels is easy

#validation_data = np.load('bottleneck_features_validation.npy')

model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(12, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train,
          epochs=10, batch_size=32,
          validation_data=(X_valid, y_valid),
          shuffle=True)
model.save_weights('bottleneck_fc_model.h5')
# Out:
# Train on 3325 samples, validate on 1425 samples
# Epoch 1/10
# 3325/3325 [==============================] - 5s 2ms/step - loss: 0.2984 - acc: 0.9149 - val_loss: 0.2840 - val_acc: 0.9167
# Epoch 2/10
# 3325/3325 [==============================] - 5s 1ms/step - loss: 0.2850 - acc: 0.9167 - val_loss: 0.2824 - val_acc: 0.9167
# Epoch 3/10
# 3325/3325 [==============================] - 5s 1ms/step - loss: 0.2840 - acc: 0.9167 - val_loss: 0.2833 - val_acc: 0.9167
# Epoch 4/10
# 1376/3325 [===========>..................] - ETA: 2s - loss: 0.2837 - acc: 0.9167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-58e280251083> in <module>()
#      23           epochs=10, batch_size=32,
#      24           validation_data=(X_valid, y_valid),
# ---> 25           shuffle=True)
#      26 model.save_weights('bottleneck_fc_model.h5')
#
# ...

# %%
test_data = np.load('bottleneck_features_test.npy')
result = model.predict(test_data)
img1 = os.listdir('./train')
img2 = os.listdir('./test')
result1 = []
result2 = []
num = 0
for i in img2:
    k = 0
    for j in range(12):
        if result[num,j] == max(result[num]):
            result1.append(i)
            result2.append(img1[j])
            k = 1
    num = num + 1
import pandas as pd
sub1 = pd.DataFrame({"file":result1, "species":result2})
#sub1 = pd.DataFrame(result1)
sub1.to_csv('submission_cut.csv', index=False)
sub1
# Out:
#               file           species
# 0    0021e90e4.png  Loose Silky-bent
# 1    003d61042.png  Loose Silky-bent
# 2    007b3da8b.png  Loose Silky-bent
# 3    0086a6340.png  Loose Silky-bent
# 4    00c47e980.png  Loose Silky-bent
# 5    00d090cde.png  Loose Silky-bent
# 6    00ef713a8.png  Loose Silky-bent
# 7    01291174f.png  Loose Silky-bent
# 8    026716f9b.png  Common Chickweed
# 9    02cfeb38d.png  Loose Silky-bent
# 10   03566743d.png  Loose Silky-bent
# 11   03a2ee656.png  Loose Silky-bent
# 12   03e322a29.png  Loose Silky-bent
# 13   03ef36742.png  Loose Silky-bent
# 14   043449b0b.png  Loose Silky-bent
# 15   0437393b1.png  Loose Silky-bent
# 16   04814f36d.png  Loose Silky-bent
# 17   05341a8a6.png  Loose Silky-bent
# 18   060450d79.png  Loose Silky-bent
# 19   060f1dc84.png  Loose Silky-bent
# 20   0625f063b.png  Loose Silky-bent
# 21   063363305.png  Loose Silky-bent
# 22   06d12f6fa.png  Loose Silky-bent
# 23   071cb3ece.png  Loose Silky-bent
# ...

# %%
sum(result)
# Out:
# array([   0.64836079,    1.70062065,   25.02752686,   84.2570343 ,
#           9.62018585,  317.0871582 ,   35.27228546,    0.6481449 ,
#         249.9679718 ,    1.01774132,    3.82383585,   64.92897034], dtype=float32)
